# %% [markdown]
# <a href="https://colab.research.google.com/github/elyasncr/Curso_Machine_learning/blob/main/App_integrado_com_looger.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests #requisitar ao servidor
import os # Interagir com o sistema operacional
import shutil # Interagir com o sistema operacional
import logging #criar log
from datetime import date


#Criação do log
FOMATAÇÂO_MSG = "%(asctime)s | %(levelname)s -> %(message)s"

logging.basicConfig(filename = "log_erro.log",
                    level = logging.DEBUG,
                   format = FOMATAÇÂO_MSG,
                   filemode = 'a')

#Teste do logger
logger = logging.getLogger()
logger.info("-="*28+"INICIALIZADO"+"-="*28)
# logger.debug('depuração')
# logger.info('informação')
# logger.warning('aviso')
# logger.error('erro')
# logger.critical('critico')


#identificando autores
class funcionario:
    def __init__(self,first,last):
        self.first = first
        self.last = last
        logging.info('Desenvolvido por: {} - {} -{}'.format(self.nome_completo,self.email,'Topdown SA'))
    @property
    def email(self):
        return '{}.{}@Topdown.com.br'.format(self.first,self.last)

    @property
    def nome_completo(self):
        return '{} {}'.format(self.first,self.last)



# Definindo a principal função do aplicativo
def baixar_arquivo(url, endereco):
    resposta = requests.get(url, stream=True)
    if resposta.status_code == requests.codes.OK:
        with open(endereco, 'wb') as novo_arquivo:
            for parte in resposta.iter_content(chunk_size=256):
                novo_arquivo.write(parte)
            print("Download finalizado. Arquivo salvo em: {}".format(endereco))
        logging.info('Download Finalizado.')
    else:
        resposta.raise_for_status()

print("-="*28,"\nBem vindo ao programa de WEB SCRAPPING""-=")
print("\n")
nome_funcionario1 = funcionario('Herick','Muller')
nome_funcionario2 = funcionario('Nikolas','Vichi')
nome_funcionario3 = funcionario('Elyas','Ribeiro')
nome_funcionario4 = funcionario('Almir','Junior')

logger.info('O programa foi iniciado') # Inicio do logger do programa

OUT1=input('Insira o endereço de armazenamento dos dados:\n')
OUT1=r'{}'.format(OUT1)
OUT2=input('Insira novamente o endereço de armazenamento dos dados:\n')
OUT2=r'{}'.format(OUT2)
while True:
    if  OUT1 == OUT2:
        OUTPUT_= OUT1

        logger.info('Endereço de armazenamento de dados foi inserido corretamente.')
        logger.info('---->>> Download IGR começou.')
    #   PDA/informacoes_consolidadas_de_beneficiarios/
        if __name__ =="__main__":
            BASE_URL= 'https://dadosabertos.ans.gov.br/FTP/PDA/informacoes_consolidadas_de_beneficiarios/{}/ben{}_{}.zip'

            OUTPUT_DIR =OUTPUT_+r'\informacoes_consolidadas_de_beneficiarios'
            path=OUTPUT_DIR
            if not os.path.exists(path):
                os.makedirs(path)
            else:
                shutil.rmtree(path)
                logger.info('Removido pasta e conteúdo antigo IGR')
                os.makedirs(path)
                logger.info('Criada nova pasta IGR')
            data_atual = str(date.today())
            end = (data_atual[0:4] + data_atual[5:7])
            end =int(end)+1
            start = int(input('Entre com o ano que será o "START" em formato numerico seguido de mês,ex:201405:\n'))
            #end =int(input('Entre com o ano atual em formato numerico seguido de mês,ex:201405:\n'))
            ufs = ['AC','AL','AM','AP','BA','CE','DF','ES','GO','MA','MG','MS','MT','PA','PB','PE','PI','PR','RJ','RN','RO','RR','RS','SC','SE','SP','TO','XX']
            for i in range(start,end):
                for uf in ufs:
                    try:

                        nome_arquivo = os.path.join(OUTPUT_DIR,'ben{}_{}.zip'.format(i, uf))
                        baixar_arquivo(BASE_URL.format(i,i,uf),nome_arquivo)

                    except Exception as erro:
                        logger.error(erro)

        else:
            pass

        #IGR
        OUTPUT= OUTPUT_+r'\IGR'
        path=OUTPUT
        if not os.path.exists(path):
            os.makedirs(path)
        else:
            shutil.rmtree(path)
            logger.info('Removido pasta e conteúdo antigo IGR')
            os.makedirs(path)
            logger.info('Criada nova pasta IGR')

        URL1 = 'https://dadosabertos.ans.gov.br/FTP/PDA/IGR/dados-gerais-das-reclamacoes/dados-gerais-das-reclamacoes-por-operadora.zip'
        URL2 = 'https://dadosabertos.ans.gov.br/FTP/PDA/IGR/igr.csv'
        URL3 = 'https://dadosabertos.ans.gov.br/FTP/PDA/IGR/igr_anual.zip'

        nome_arquivo1 = os.path.join(OUTPUT,'dados-gerais-das-reclamacoes-por-operadora.zip')
        nome_arquivo2 = os.path.join(OUTPUT,'igr.csv')
        nome_arquivo3 = os.path.join(OUTPUT,'igr_anual.zip')

        baixar_arquivo(URL1,nome_arquivo1)
        baixar_arquivo(URL2,nome_arquivo2)
        baixar_arquivo(URL3,nome_arquivo3)


        #MICRODADOS dados_dbc
        if __name__ =="__main__":
            BASE_URL= 'https://dadosabertos.ans.gov.br/FTP/Base_de_dados/Microdados/dados_dbc/ressarcimento_ao_sus/tb_res_{}.dbc'

            OUTPUT_DIR = OUTPUT_+r'\Microdados\dados_dbc\ressarcimento_ao_sus'
            path=OUTPUT_DIR
            if not os.path.exists(path):
                os.makedirs(path)
            else:
                shutil.rmtree(path)
                logger.info('Removido pasta e conteúdo antigo ressarcimento_ao_sus')
                os.makedirs(path)
                logger.info('Criada nova pasta ressarcimento_ao_sus')
            data_atual = str(date.today())
            end = (data_atual[0:4])
            end =int(end)+1
            start = int((data_atual[0:4]))  #atualizado 01/12/2021
            #end =int(input('Entre com o ano atual em formato numerico seguido de mês,ex:201405:\n'))

            for i in range(start,end):
                try:
                    nome_arquivo = os.path.join(OUTPUT_DIR,'tb_res_{}.dbc'.format(i))
                    baixar_arquivo(BASE_URL.format(i),nome_arquivo)

                except Exception as erro:
                    logger.error(erro)

        else:
            pass


        #MICRODADOS dados_dbc
        if __name__ =="__main__":
            BASE_URL= 'https://dadosabertos.ans.gov.br/FTP/Base_de_dados/Microdados/dados_dbc/planos/tb_pl_{}-{}.dbc'

            OUTPUT_DIR = OUTPUT_+r'\Microdados\dados_dbc\planos'
            path=OUTPUT_DIR
            if not os.path.exists(path):
                os.makedirs(path)
            else:
                shutil.rmtree(path)
                logger.info('Removido pasta e conteúdo antigo planos')
                os.makedirs(path)
                logger.info('Criada nova pasta planos')
            data_atual = str(date.today())
            end = (data_atual[0:4])
            end =int(end)+1
            start = int((data_atual[0:4]))
            #end =int(input('Entre com o ano atual em formato numerico seguido de mês,ex:201405:\n'))
            meses = ['01','02','03','04','05','06','07','08','09','10','11','12']
            for i in range(start,end):
                for mes in (meses):
                    try:
                        nome_arquivo = os.path.join(OUTPUT_DIR,'tb_pl_{}-{}.dbc'.format(i,mes))
                        baixar_arquivo(BASE_URL.format(i,mes),nome_arquivo)

                    except Exception as erro:
                        logger.error(erro)

        else:
            pass
        #MICRODADOS OPERADORAS

        if __name__ =="__main__":
            BASE_URL= 'https://dadosabertos.ans.gov.br/FTP/Base_de_dados/Microdados/dados_dbc/operadoras/oper_com_registro_ativo/tb_opa_{}-{}.dbc'

            OUTPUT_DIR = OUTPUT_+r'\Microdados\operadoras\oper_com_registro_ativo'
            path=OUTPUT_DIR
            if not os.path.exists(path):
                os.makedirs(path)
            else:
                shutil.rmtree(path)
                logger.info('Removido pasta e conteúdo antigo oper_com_registro_ativo')
                os.makedirs(path)
                logger.info('Criada nova pasta oper_com_registro_ativo')
            data_atual = str(date.today())
            end = (data_atual[0:4])
            end =int(end)+1
            start = int((data_atual[0:4]))
            #end =int(input('Entre com o ano atual em formato numerico seguido de mês,ex:201405:\n'))
            meses = ['01','02','03','04','05','06','07','08','09','10','11','12']
            for i in range(start,end):
                for mes in (meses):
                    try:
                        nome_arquivo = os.path.join(OUTPUT_DIR,'tb_opa_{}-{}.dbc'.format(i,mes))
                        baixar_arquivo(BASE_URL.format(i,mes),nome_arquivo)

                    except Exception as erro:
                        logger.error(erro)

        else:
            pass


        #Microdados/dados_dbc/operadoras/receita_de_contraprest_e_despesas/tb_rc_2001.dbc

        if __name__ =="__main__":
            BASE_URL= 'https://dadosabertos.ans.gov.br/FTP/Base_de_dados/Microdados/dados_dbc/operadoras/receita_de_contraprest_e_despesas/tb_rc_{}.dbc'

            OUTPUT_DIR = OUTPUT_+r'\Microdados\operadoras\receita_de_contraprest_e_despesas'
            path=OUTPUT_DIR
            if not os.path.exists(path):
                os.makedirs(path)
            else:
                shutil.rmtree(path)
                logger.info('Removido pasta e conteúdo antigo receita_de_contraprest_e_despesas')
                os.makedirs(path)
                logger.info('Criada nova pasta receita_de_contraprest_e_despesas')
            data_atual = str(date.today())
            end = (data_atual[0:4])
            end =int(end)+1
            start = int((data_atual[0:4]))
            #end =int(input('Entre com o ano atual em formato numerico seguido de mês,ex:201405:\n'))
            meses = ['01','02','03','04','05','06','07','08','09','10','11','12']
            for i in range(start,end):

                try:
                    nome_arquivo = os.path.join(OUTPUT_DIR,'tb_rc_{}.dbc'.format(i))
                    baixar_arquivo(BASE_URL.format(i),nome_arquivo)

                except Exception as erro:
                    logger.error(erro)

        else:
            pass

        #MICRODADOS DEMANDAS
        if __name__ =="__main__":
            BASE_URL= 'https://dadosabertos.ans.gov.br/FTP/Base_de_dados/Microdados/dados_dbc/demandas/informacoes/tb_inf_{}-{}.dbc'

            OUTPUT_DIR =OUTPUT_+r"\Microdados\demandas\informacoes"
            path=OUTPUT_DIR
            if not os.path.exists(path):
                os.makedirs(path)
            else:
                shutil.rmtree(path)
                logger.info('Removido pasta e conteúdo antigo informacoes')
                os.makedirs(path)
                logger.info('Criada nova pasta informacoes')
            data_atual = str(date.today())
            end = (data_atual[0:4])
            end =int(end)+1
            start = int((data_atual[0:4]))
            #end =int(input('Entre com o ano atual em formato numerico seguido de mês,ex:201405:\n'))
            meses = ['01','02','03','04','05','06','07','08','09','10','11','12']
            for i in range(start,end):
                for mes in (meses):
                    try:
                        nome_arquivo = os.path.join(OUTPUT_DIR,'tb_inf_{}-{}.dbc'.format(i,mes))
                        baixar_arquivo(BASE_URL.format(i,mes),nome_arquivo)

                    except Exception as erro:
                        logger.error(erro)

        else:
            pass

        #Microdados/dados_dbc/demandas/nip
        if __name__ =="__main__":
            BASE_URL= 'https://dadosabertos.ans.gov.br/FTP/Base_de_dados/Microdados/dados_dbc/demandas/nip/tb_nip_{}-{}.dbc'

            OUTPUT_DIR = OUTPUT_+r"\Microdados\demandas\nip"
            path=OUTPUT_DIR
            if not os.path.exists(path):
                os.makedirs(path)
            else:
                shutil.rmtree(path)
                logger.info('Removido pasta e conteúdo antigo nip')
                os.makedirs(path)
                logger.info('Criada nova pasta nip')
            data_atual = str(date.today())
            end = (data_atual[0:4])
            end =int(end)+1
            start = int((data_atual[0:4]))
            #end =int(input('Entre com o ano atual em formato numerico seguido de mês,ex:201405:\n'))
            meses = ['01','02','03','04','05','06','07','08','09','10','11','12']
            for i in range(start,end):
                for mes in (meses):
                    try:
                        nome_arquivo = os.path.join(OUTPUT_DIR,'tb_nip_{}-{}.dbc'.format(i,mes))
                        baixar_arquivo(BASE_URL.format(i,mes),nome_arquivo)

                    except Exception as erro:
                        logger.error(erro)

        else:
            pass

        #Microdados/dados_dbc/demandas/reclamacoes
        if __name__ =="__main__":
            BASE_URL= 'https://dadosabertos.ans.gov.br/FTP/Base_de_dados/Microdados/dados_dbc/demandas/reclamacoes/tb_rec_{}-{}.dbc'

            OUTPUT_DIR = OUTPUT_+r"\Microdados\demandas\reclamacoes"
            path=OUTPUT_DIR
            if not os.path.exists(path):
                os.makedirs(path)
            else:
                shutil.rmtree(path)
                logger.info('Removido pasta e conteúdo antigo reclamacoes')
                os.makedirs(path)
                logger.info('Criada nova pasta reclamacoes')
            data_atual = str(date.today())
            end = (data_atual[0:4])
            end =int(end)+1
            start = int((data_atual[0:4]))
            #end =int(input('Entre com o ano atual em formato numerico seguido de mês,ex:201405:\n'))
            meses = ['01','02','03','04','05','06','07','08','09','10','11','12']
            for i in range(start,end):
                for mes in (meses):
                    try:
                        nome_arquivo = os.path.join(OUTPUT_DIR,'tb_rec_{}-{}.dbc'.format(i,mes))
                        baixar_arquivo(BASE_URL.format(i,mes),nome_arquivo)

                    except Exception as erro:
                        logger.error(erro)

        else:
            pass

        #MICRODADOS BENEFICIARIOS
        if __name__ =="__main__":
            BASE_URL= 'https://dadosabertos.ans.gov.br/FTP/Base_de_dados/Microdados/dados_dbc/beneficiarios/uf_regiao_metropolitana_e_capital/tb_br_{}-{}.dbc'

            OUTPUT_DIR =OUTPUT_+r"\Microdados\beneficiarios\uf_regiao_metropolitana_e_capital"
            path=OUTPUT_DIR
            if not os.path.exists(path):
                os.makedirs(path)
            else:
                shutil.rmtree(path)
                logger.info('Removido pasta e conteúdo antigo uf_regiao_metropolitana_e_capital')
                os.makedirs(path)
                logger.info('Criada nova pasta uf_regiao_metropolitana_e_capital')
            data_atual = str(date.today())
            end = (data_atual[0:4])
            end =int(end)+1
            start = int((data_atual[0:4]))
            #end =int(input('Entre com o ano atual em formato numerico seguido de mês,ex:201405:\n'))
            meses = ['01','02','03','04','05','06','07','08','09','10','11','12']
            for i in range(start,end):
                for mes in (meses):
                    try:
                        nome_arquivo = os.path.join(OUTPUT_DIR,'tb_br_{}-{}.dbc'.format(i,mes))
                        baixar_arquivo(BASE_URL.format(i,mes),nome_arquivo)

                    except Exception as erro:
                        logger.error(erro)

        else:
            pass

        #Microdados/dados_dbc/beneficiarios/taxa_cobertura
        if __name__ =="__main__":
            BASE_URL= 'https://dadosabertos.ans.gov.br/FTP/Base_de_dados/Microdados/dados_dbc/beneficiarios/taxa_cobertura/tb_tx_{}-{}.dbc'

            OUTPUT_DIR = OUTPUT_+r"\Microdados\beneficiarios\taxa_cobertura"
            path=OUTPUT_DIR
            if not os.path.exists(path):
                os.makedirs(path)
            else:
                shutil.rmtree(path)
                logger.info('Removido pasta e conteúdo antigo taxa_cobertura')
                os.makedirs(path)
                logger.info('Criada nova pasta taxa_cobertura')
            data_atual = str(date.today())
            end = (data_atual[0:4])
            end =int(end)+1
            start = int((data_atual[0:4]))
            #end =int(input('Entre com o ano atual em formato numerico seguido de mês,ex:201405:\n'))
            meses = ['01','02','03','04','05','06','07','08','09','10','11','12']
            for i in range(start,end):
                for mes in (meses):
                    try:
                        nome_arquivo = os.path.join(OUTPUT_DIR,'tb_tx_{}-{}.dbc'.format(i,mes))
                        baixar_arquivo(BASE_URL.format(i,mes),nome_arquivo)

                    except Exception as erro:
                        logger.error(erro)

        else:
            pass

        #Microdados/dados_dbc/beneficiarios/operadoras
        if __name__ =="__main__":
            BASE_URL= 'https://dadosabertos.ans.gov.br/FTP/Base_de_dados/Microdados/dados_dbc/beneficiarios/operadoras/tb_cc_{}-{}.dbc'

            OUTPUT_DIR = OUTPUT_+r"\Microdados\beneficiarios\operadoras"
            path=OUTPUT_DIR
            if not os.path.exists(path):
                os.makedirs(path)
            else:
                shutil.rmtree(path)
                logger.info('Removido pasta e conteúdo antigo operadoras')
                os.makedirs(path)
                logger.info('Criada nova pasta operadoras')
            data_atual = str(date.today())
            end = (data_atual[0:4])
            end =int(end)+1
            start = int((data_atual[0:4]))
            #end =int(input('Entre com o ano atual em formato numerico seguido de mês,ex:201405:\n'))
            meses = ['01','02','03','04','05','06','07','08','09','10','11','12']
            for i in range(start,end):
                for mes in (meses):
                    try:
                        nome_arquivo = os.path.join(OUTPUT_DIR,'tb_cc_{}-{}.dbc'.format(i,mes))
                        baixar_arquivo(BASE_URL.format(i,mes),nome_arquivo)

                    except Exception as erro:
                        logger.error(erro)

        else:
            pass

        #Microdados/dados_dbc/beneficiarios/municipios

        if __name__ =="__main__":
            BASE_URL= 'https://dadosabertos.ans.gov.br/FTP/Base_de_dados/Microdados/dados_dbc/beneficiarios/municipios/tb_bb_{}-{}.dbc'

            OUTPUT_DIR = OUTPUT_+r"\Microdados\beneficiarios\municipios"
            path=OUTPUT_DIR
            if not os.path.exists(path):
                os.makedirs(path)
            else:
                shutil.rmtree(path)
                logger.info('Removido pasta e conteúdo antigo municipios')
                os.makedirs(path)
                logger.info('Criada nova pasta municipios')
            data_atual = str(date.today())
            end = (data_atual[0:4])
            end =int(end)+1
            start = int((data_atual[0:4]))
            #end =int(input('Entre com o ano atual em formato numerico seguido de mês,ex:201405:\n'))
            meses = ['01','02','03','04','05','06','07','08','09','10','11','12']
            for i in range(start,end):
                for mes in (meses):
                    try:
                        nome_arquivo = os.path.join(OUTPUT_DIR,'tb_bb_{}-{}.dbc'.format(i,mes))
                        baixar_arquivo(BASE_URL.format(i,mes),nome_arquivo)

                    except Exception as erro:
                        logger.error(erro)

        else:
            pass

        #Microdados/dados_dbc/beneficiarios/mortalidade_por_operadora
        if __name__ =="__main__":
            BASE_URL= 'https://dadosabertos.ans.gov.br/FTP/Base_de_dados/Microdados/dados_dbc/beneficiarios/mortalidade_por_operadora/tb_mm_{}.dbc'
            OUTPUT_DIR = OUTPUT_+r"\Microdados\beneficiarios\mortalidade_por_operadora"
            path=OUTPUT_DIR
            if not os.path.exists(path):
                os.makedirs(path)
            else:
                shutil.rmtree(path)
                logger.info('Removido pasta e conteúdo antigo mortalidade_por_operadora')
                os.makedirs(path)
                logger.info('Criada nova pasta mortalidade_por_operadora')
            data_atual = str(date.today())
            end = (data_atual[0:4])
            end =int(end)+1
            start = int((data_atual[0:4]))
            #end =int(input('Entre com o ano atual em formato numerico seguido de mês,ex:201405:\n'))
            meses = ['01','02','03','04','05','06','07','08','09','10','11','12']
            for i in range(start,end):

                try:
                    nome_arquivo = os.path.join(OUTPUT_DIR,'tb_mm_{}.dbc'.format(i))
                    baixar_arquivo(BASE_URL.format(i),nome_arquivo)

                except Exception as erro:
                    logger.error(erro)
            logger.info("Downloads FINALIZADOS")
            logger.info("-="*28+"FINALIZADDO"+"-="*28)
            break

        else:
            print('Endereço de armazenamento de dados diferem.\nCorrija o endereço de armazenamento.\nAplicação será encerrada.')
            print("-="*52)
            logger.error('Endereço de armazenamento de dados diferem.')
            break

print('Downloads FINALIZADOS')
print("-="*52)
